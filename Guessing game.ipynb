# %%
import random
name = input("What is your name : ")
print("All the best !", name)

words = ['rainbow', 'computer', 'science', 'programming', 
        'python', 'mathematics', 'player', 'condition', 
        'reverse', 'water', 'board', 'geeks'] 

word = random.choice(words)

guesses = ""

turns = 5

while turns > 0:
    failed = 0
    for char in word:
        if char in guesses:
            print(char)
            
        else:
            print("_")
            failed += 1
            
    if failed == 0:
        print("YOU WIN !!")
        print("The word is", word)
        break
        
    guess = input("Enter a character : ")
    guesses += guess
    
    if guess not in word:
        turns -= 1
        print("The character entered is incorrect")
        print("You have", turns, "guesses left")
        
        if turns == 0:
            print("Better luck next time !!")
# Out:
# What is your name : Tanishq
# All the best ! Tanishq
# _
# _
# _
# _
# _
# _
# _
# Enter a character : a
# The character entered is incorrect
# You have 4 guesses left
# _
# _
# _
# _
# _
# _
# _
# Enter a character : c
# The character entered is incorrect
# You have 3 guesses left
# _
# _
# _
# _
# _
# _
# _
# Enter a character : s
# _
# _
# _
# _
# _
# s
# _
# Enter a character : e
# _
# e
# _
# e
# _
# s
# e
# Enter a character : r
# r
# e
# _
# e
# r
# s
# e
# Enter a character : v
# r
# e
# v
# e
# r
# s
# e
# YOU WIN !!
# The word is reverse
